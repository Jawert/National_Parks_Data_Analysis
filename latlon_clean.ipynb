# %%
#imports
import pandas as pd
import re
import ast

# %%
# Out:
#       trail_id                                               name  \
# 0     10020048                            Harding Ice Field Trail
# 1     10236086                         Mount Healy Overlook Trail
# 2     10267857                                 Exit Glacier Trail
# 3     10236076                               Horseshoe Lake Trail
# 4     10236082                                 Triple Lakes Trail
# ...        ...                                                ...
# 3308  10008302               Silversword Loop Via Halemau'u Trail
# 3309  10236001                                Keonehe'ehe'e Trail
# 3310  10258707                     Red Hill Overlook Summit Trail
# 3311  10014989                                        Kaupo Trail
# 3312  10259465  Ka Lu'u o ka O'o Cinder Cone via Crater and Sl...
#
#                        area_name             city_name state_name  \
# 0     Kenai Fjords National Park                Seward     Alaska
# 1           Denali National Park  Denali National Park     Alaska
# 2     Kenai Fjords National Park                Seward     Alaska
# 3           Denali National Park  Denali National Park     Alaska
# 4           Denali National Park  Denali National Park     Alaska
# ...                          ...                   ...        ...
# 3308     Haleakala National Park                  Kula       Maui
# 3309     Haleakala National Park                  Kula       Maui
# 3310     Haleakala National Park                  Kula       Maui
# 3311     Haleakala National Park                  Kula       Maui
# 3312     Haleakala National Park                  Kula       Maui
#
#        country_name                                         _geoloc  \
# 0     United States            {'lat': 60.18852, 'lng': -149.63156}
# 1     United States            {'lat': 63.73049, 'lng': -148.91968}
# 2     United States              {'lat': 60.18879, 'lng': -149.631}
# 3     United States              {'lat': 63.73661, 'lng': -148.915}
# 4     United States            {'lat': 63.73319, 'lng': -148.89682}
# ...             ...                                             ...
# 3308         Hawaii            {'lat': 20.75275, 'lng': -156.22884}
# 3309         Hawaii  {'lat': 20.714480000000002, 'lng': -156.25072}
# 3310         Hawaii            {'lat': 20.71007, 'lng': -156.25357}
# 3311         Hawaii              {'lat': 20.64981, 'lng': -156.137}
# 3312         Hawaii            {'lat': 20.71449, 'lng': -156.25085}
#
#       popularity     length  elevation_gain  difficulty_rating    route_type  \
# 0        24.8931  15610.598       1161.8976                  5  out and back
# 1        18.0311   6920.162        507.7968                  3  out and back
# 2        17.7821   2896.812         81.9912                  1  out and back
# 3        16.2674   3379.614        119.7864                  1          loop
# 4        12.5935  29772.790       1124.7120                  5  out and back
# ...          ...        ...             ...                ...           ...
# 3308      9.3861  20116.750       1105.8144                  5          loop
# 3309      9.1555  28324.384       1171.9560                  5  out and back
# 3310      8.5066    321.868          3.9624                  1  out and back
# 3311      8.3240  19312.080       1670.9136                  5  out and back
# 3312      2.4176   8368.568        510.8448                  3          loop
#
#       visitor_usage  avg_rating  num_reviews  \
# 0               3.0         5.0          423
# 1               1.0         4.5          260
# 2               3.0         4.5          224
# 3               2.0         4.5          237
# 4               1.0         4.5          110
# ...             ...         ...          ...
# 3308            2.0         4.5           43
# 3309            2.0         5.0           22
# 3310            NaN         4.5           31
# 3311            1.0         4.0            8
# 3312            2.0         4.5           45
#
#                                                features  \
# 0     ['dogs-no', 'forest', 'river', 'views', 'water...
# 1     ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2     ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3     ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4     ['dogs-no', 'lake', 'views', 'wild-flowers', '...
# ...                                                 ...
# 3308               ['dogs-no', 'views', 'wild-flowers']
# 3309                   ['dogs-no', 'views', 'wildlife']
# 3310                       ['dogs-no', 'kids', 'views']
# 3311                   ['dogs-no', 'views', 'wildlife']
# 3312                                          ['views']
#
#                                              activities units
# 0     ['birding', 'camping', 'hiking', 'nature-trips...     i
# 1     ['birding', 'camping', 'hiking', 'nature-trips...     i
# 2                                 ['hiking', 'walking']     i
# 3     ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 4     ['birding', 'fishing', 'hiking', 'nature-trips...     i
# ...                                                 ...   ...
# 3308              ['birding', 'hiking', 'nature-trips']     m
# 3309               ['backpacking', 'camping', 'hiking']     m
# 3310                              ['hiking', 'walking']     m
# 3311                                         ['hiking']     m
# 3312                                         ['hiking']     m
#
# [3313 rows x 18 columns]

# %%
#bringing the csv data into a dataframe
parks_data=pd.read_csv('national_park_trails.csv')

# %%
#extracting lat/lon from each into a list
latlist=[]
lonlist=[]
for index,row in parks_data.iterrows():
    lat_lon_dict=ast.literal_eval(row['_geoloc'])
    lat=lat_lon_dict['lat']
    lon=lat_lon_dict['lng']
    latlist.append(lat)
    lonlist.append(lon)

# %%
#adding separate lat and lon columns to parks_data and inserting the data
parks_data['lat']=latlist
parks_data['lon']=lonlist

# %%
#verifying that the insertion worked correctly
correct_count=0
for index, row in parks_data.iterrows():
    geoloc_dict=ast.literal_eval(row['_geoloc'])
    geoloc_lat=geoloc_dict['lat']
    geoloc_lon=geoloc_dict['lng']
    if row['lat']==geoloc_lat and row['lon']==geoloc_lon:
        correct_count +=1
    else:
        print('lat/lon disagreement for ' + row['name'])
print(correct_count)
# Out:
# 3313

# %%
#seeing that the above worked, dropping the _geoloc column from the dataframe
parks_data.drop(columns=['_geoloc'])
# Out:
#       trail_id                                               name  \
# 0     10020048                            Harding Ice Field Trail
# 1     10236086                         Mount Healy Overlook Trail
# 2     10267857                                 Exit Glacier Trail
# 3     10236076                               Horseshoe Lake Trail
# 4     10236082                                 Triple Lakes Trail
# ...        ...                                                ...
# 3308  10008302               Silversword Loop Via Halemau'u Trail
# 3309  10236001                                Keonehe'ehe'e Trail
# 3310  10258707                     Red Hill Overlook Summit Trail
# 3311  10014989                                        Kaupo Trail
# 3312  10259465  Ka Lu'u o ka O'o Cinder Cone via Crater and Sl...
#
#                        area_name             city_name state_name  \
# 0     Kenai Fjords National Park                Seward     Alaska
# 1           Denali National Park  Denali National Park     Alaska
# 2     Kenai Fjords National Park                Seward     Alaska
# 3           Denali National Park  Denali National Park     Alaska
# 4           Denali National Park  Denali National Park     Alaska
# ...                          ...                   ...        ...
# 3308     Haleakala National Park                  Kula       Maui
# 3309     Haleakala National Park                  Kula       Maui
# 3310     Haleakala National Park                  Kula       Maui
# 3311     Haleakala National Park                  Kula       Maui
# 3312     Haleakala National Park                  Kula       Maui
#
#        country_name  popularity     length  elevation_gain  difficulty_rating  \
# 0     United States     24.8931  15610.598       1161.8976                  5
# 1     United States     18.0311   6920.162        507.7968                  3
# 2     United States     17.7821   2896.812         81.9912                  1
# 3     United States     16.2674   3379.614        119.7864                  1
# 4     United States     12.5935  29772.790       1124.7120                  5
# ...             ...         ...        ...             ...                ...
# 3308         Hawaii      9.3861  20116.750       1105.8144                  5
# 3309         Hawaii      9.1555  28324.384       1171.9560                  5
# 3310         Hawaii      8.5066    321.868          3.9624                  1
# 3311         Hawaii      8.3240  19312.080       1670.9136                  5
# 3312         Hawaii      2.4176   8368.568        510.8448                  3
#
#         route_type  visitor_usage  avg_rating  num_reviews  \
# 0     out and back            3.0         5.0          423
# 1     out and back            1.0         4.5          260
# 2     out and back            3.0         4.5          224
# 3             loop            2.0         4.5          237
# 4     out and back            1.0         4.5          110
# ...            ...            ...         ...          ...
# 3308          loop            2.0         4.5           43
# 3309  out and back            2.0         5.0           22
# 3310  out and back            NaN         4.5           31
# 3311  out and back            1.0         4.0            8
# 3312          loop            2.0         4.5           45
#
#                                                features  \
# 0     ['dogs-no', 'forest', 'river', 'views', 'water...
# 1     ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2     ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3     ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4     ['dogs-no', 'lake', 'views', 'wild-flowers', '...
# ...                                                 ...
# 3308               ['dogs-no', 'views', 'wild-flowers']
# 3309                   ['dogs-no', 'views', 'wildlife']
# 3310                       ['dogs-no', 'kids', 'views']
# 3311                   ['dogs-no', 'views', 'wildlife']
# 3312                                          ['views']
#
#                                              activities units       lat  \
# 0     ['birding', 'camping', 'hiking', 'nature-trips...     i  60.18852
# 1     ['birding', 'camping', 'hiking', 'nature-trips...     i  63.73049
# 2                                 ['hiking', 'walking']     i  60.18879
# 3     ['birding', 'hiking', 'nature-trips', 'trail-r...     i  63.73661
# 4     ['birding', 'fishing', 'hiking', 'nature-trips...     i  63.73319
# ...                                                 ...   ...       ...
# 3308              ['birding', 'hiking', 'nature-trips']     m  20.75275
# 3309               ['backpacking', 'camping', 'hiking']     m  20.71448
# 3310                              ['hiking', 'walking']     m  20.71007
# 3311                                         ['hiking']     m  20.64981
# 3312                                         ['hiking']     m  20.71449
#
#             lon
# 0    -149.63156
# 1    -148.91968
# 2    -149.63100
# 3    -148.91500
# 4    -148.89682
# ...         ...
# 3308 -156.22884
# 3309 -156.25072
# 3310 -156.25357
# 3311 -156.13700
# 3312 -156.25085
#
# [3313 rows x 19 columns]

# %%
#writing parks_data to a new csv and preserving original dataset
parks_data.to_csv('national_park_trails_rev2.csv')

# %%
#importing the new sheet to double check
parks_data_rev2=pd.read_csv('national_park_trails_rev2.csv')
parks_data_rev2
# Out:
#       Unnamed: 0  trail_id                                               name  \
# 0              0  10020048                            Harding Ice Field Trail
# 1              1  10236086                         Mount Healy Overlook Trail
# 2              2  10267857                                 Exit Glacier Trail
# 3              3  10236076                               Horseshoe Lake Trail
# 4              4  10236082                                 Triple Lakes Trail
# ...          ...       ...                                                ...
# 3308        3308  10008302               Silversword Loop Via Halemau'u Trail
# 3309        3309  10236001                                Keonehe'ehe'e Trail
# 3310        3310  10258707                     Red Hill Overlook Summit Trail
# 3311        3311  10014989                                        Kaupo Trail
# 3312        3312  10259465  Ka Lu'u o ka O'o Cinder Cone via Crater and Sl...
#
#                        area_name             city_name state_name  \
# 0     Kenai Fjords National Park                Seward     Alaska
# 1           Denali National Park  Denali National Park     Alaska
# 2     Kenai Fjords National Park                Seward     Alaska
# 3           Denali National Park  Denali National Park     Alaska
# 4           Denali National Park  Denali National Park     Alaska
# ...                          ...                   ...        ...
# 3308     Haleakala National Park                  Kula       Maui
# 3309     Haleakala National Park                  Kula       Maui
# 3310     Haleakala National Park                  Kula       Maui
# 3311     Haleakala National Park                  Kula       Maui
# 3312     Haleakala National Park                  Kula       Maui
#
#        country_name                                         _geoloc  \
# 0     United States            {'lat': 60.18852, 'lng': -149.63156}
# 1     United States            {'lat': 63.73049, 'lng': -148.91968}
# 2     United States              {'lat': 60.18879, 'lng': -149.631}
# 3     United States              {'lat': 63.73661, 'lng': -148.915}
# 4     United States            {'lat': 63.73319, 'lng': -148.89682}
# ...             ...                                             ...
# 3308         Hawaii            {'lat': 20.75275, 'lng': -156.22884}
# 3309         Hawaii  {'lat': 20.714480000000002, 'lng': -156.25072}
# 3310         Hawaii            {'lat': 20.71007, 'lng': -156.25357}
# 3311         Hawaii              {'lat': 20.64981, 'lng': -156.137}
# 3312         Hawaii            {'lat': 20.71449, 'lng': -156.25085}
#
#       popularity     length  ...  difficulty_rating    route_type  \
# 0        24.8931  15610.598  ...                  5  out and back
# 1        18.0311   6920.162  ...                  3  out and back
# 2        17.7821   2896.812  ...                  1  out and back
# 3        16.2674   3379.614  ...                  1          loop
# 4        12.5935  29772.790  ...                  5  out and back
# ...          ...        ...  ...                ...           ...
# 3308      9.3861  20116.750  ...                  5          loop
# 3309      9.1555  28324.384  ...                  5  out and back
# 3310      8.5066    321.868  ...                  1  out and back
# 3311      8.3240  19312.080  ...                  5  out and back
# 3312      2.4176   8368.568  ...                  3          loop
#
#      visitor_usage  avg_rating  num_reviews  \
# 0              3.0         5.0          423
# 1              1.0         4.5          260
# 2              3.0         4.5          224
# 3              2.0         4.5          237
# 4              1.0         4.5          110
# ...            ...         ...          ...
# 3308           2.0         4.5           43
# 3309           2.0         5.0           22
# 3310           NaN         4.5           31
# 3311           1.0         4.0            8
# 3312           2.0         4.5           45
#
#                                                features  \
# 0     ['dogs-no', 'forest', 'river', 'views', 'water...
# 1     ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2     ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3     ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4     ['dogs-no', 'lake', 'views', 'wild-flowers', '...
# ...                                                 ...
# 3308               ['dogs-no', 'views', 'wild-flowers']
# 3309                   ['dogs-no', 'views', 'wildlife']
# 3310                       ['dogs-no', 'kids', 'views']
# 3311                   ['dogs-no', 'views', 'wildlife']
# 3312                                          ['views']
#
#                                              activities units       lat  \
# 0     ['birding', 'camping', 'hiking', 'nature-trips...     i  60.18852
# 1     ['birding', 'camping', 'hiking', 'nature-trips...     i  63.73049
# 2                                 ['hiking', 'walking']     i  60.18879
# 3     ['birding', 'hiking', 'nature-trips', 'trail-r...     i  63.73661
# 4     ['birding', 'fishing', 'hiking', 'nature-trips...     i  63.73319
# ...                                                 ...   ...       ...
# 3308              ['birding', 'hiking', 'nature-trips']     m  20.75275
# 3309               ['backpacking', 'camping', 'hiking']     m  20.71448
# 3310                              ['hiking', 'walking']     m  20.71007
# 3311                                         ['hiking']     m  20.64981
# 3312                                         ['hiking']     m  20.71449
#
#             lon
# 0    -149.63156
# 1    -148.91968
# 2    -149.63100
# 3    -148.91500
# 4    -148.89682
# ...         ...
# 3308 -156.22884
# 3309 -156.25072
# 3310 -156.25357
# 3311 -156.13700
# 3312 -156.25085
#
# [3313 rows x 21 columns]
